# %%
import pandas

# %% [markdown]
# #Leemos el archivo .csv y lo convertimos en DataFrame

# %%
df = pandas.read_csv("C:\\Users\\pablo\\Documents\\pandas.csv")

# %%
# Visualizar el Data Frame

# %%
df
# Out:
#                Método                                  Descripción Breve
# 0       pd.read_csv()     Lee un archivo CSV y lo convierte en DataFrame
# 1           df.head()           Muestra las primeras filas del DataFrame
# 2           df.tail()            Muestra las últimas filas del DataFrame
# 3           df.info()  Proporciona información sobre el DataFrame (ti...
# 4       df.describe()  Genera estadísticas descriptivas de las column...
# 5            df.shape  Devuelve una tupla con (filas y columnas) del ...
# 6          df.columns                Muestra los nombres de las columnas
# 7         df.isnull()                    Detecta valores faltantes (NaN)
# 8         df.dropna()     Elimina filas o columnas con valores faltantes
# 9         df.fillna()  Rellena valores faltantes con un valor específico
# 10       df.groupby()  Agrupa datos según categorías para operaciones...
# 11   df.sort_values()         Ordena el DataFrame por valores de columna
# ...
